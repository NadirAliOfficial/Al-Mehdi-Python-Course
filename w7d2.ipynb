# %%
import matplotlib.pyplot as plt

# %%
import urllib.parse, base64
s = "cGljb0NURntjMDBrMWVfbTBuc3Rlcl9sMHZlc19jMDBraWVzX0IzQUQ5NEMyfQ%3D%3D"
b64 = urllib.parse.unquote(s)            
plain = base64.b64decode(b64).decode()  
print(plain)
# Out:
# picoCTF{c00k1e_m0nster_l0ves_c00kies_B3AD94C2}
