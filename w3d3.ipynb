# %%
my_tuple = (1, 'apple', 3.5) 
print(my_tuple)
# Out:
# (1, 'apple', 3.5)

# %%
my_tuple = (10, 20, 30, 40)
print(my_tuple[-1])
# Out:
# 40

# %%
my_tuple = ('apple', 'banana', 'cherry')
fruit1, fruit2, fruit3 = my_tuple
print(fruit1, fruit2, fruit3)
# Out:
# apple banana cherry

# %%
my_tuple.append("Japani")
# It will give an error because tuples are immutable
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 my_tuple.append("Japani")
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
{"nadir": 21} # Dictionary with a string key and an integer value

(12, 11, 15, "nadir") # A tuple with three integers and a string

[12, 11, 15, "nadir"] # A list with three integers and a string
# Out:
# ()
